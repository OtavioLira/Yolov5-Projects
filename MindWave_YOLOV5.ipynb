# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16026, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 16026 (delta 32), reused 24 (delta 13), pack-reused 15967
# Receiving objects: 100% (16026/16026), 14.69 MiB | 22.48 MiB/s, done.
# Resolving deltas: 100% (10998/10998), done.

# %% [markdown]
# Com o código do YOLO no seu computador, baixe as dependências necessárias para fazer ele rodar:

# %%
! pip install -r yolov5/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# ...

# %%
! cp /content/drive/MyDrive/TRATOR/trator.yaml yolov5/data
! cp -r /content/drive/MyDrive/TRATOR/images /content
! cp -r /content/drive/MyDrive/TRATOR/labels /content
! cp -r /content/drive/MyDrive/TRATOR/test /content

# %%
from PIL import Image
import os

input_folder = "/content/images/treino"
output_folder = "/content/images/train"
target_size = (360, 640)

for filename in os.listdir(input_folder):
    img = Image.open(os.path.join(input_folder, filename))
    img = img.resize(target_size, Image.ANTIALIAS)
    img.save(os.path.join(output_folder, filename))

input_folder = "/content/images/validacao"
output_folder = "/content/images/val"

for filename in os.listdir(input_folder):
    img = Image.open(os.path.join(input_folder, filename))
    img = img.resize(target_size, Image.ANTIALIAS)
    img.save(os.path.join(output_folder, filename))
# Out:
# <ipython-input-5-1e6897193282>:10: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)
# <ipython-input-5-1e6897193282>:18: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize(target_size, Image.ANTIALIAS)

# %%
! python yolov5/train.py --data trator.yaml --weights yolov5s.pt --img 640 --epochs 40
# Out:
# 2023-10-27 12:50:52.936679: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-27 12:50:52.936752: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-27 12:50:52.936799: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
import subprocess


def get_latest_train_run_folder():
    subfolders = [f.path for f in os.scandir('/content/yolov5/runs/train') if f.is_dir()]
    latest_folder = max(subfolders, key=os.path.getctime, default=None)
    return latest_folder

latest_run = get_latest_train_run_folder()


result = subprocess.run(f'python /content/yolov5/detect.py --weights {latest_run}/weights/best.pt --img 640 --source /content/test --data /content/yolov5/data/trator.yaml', shell=True)
if result.returncode == 0:
    print("Comando executado com sucesso")
else:
    print(f"Erro durante a execução.")
# Out:
# Comando executado com sucesso
